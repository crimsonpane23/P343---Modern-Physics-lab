# %%
# Least Square Fitting with Error Analysis
# Using numpy, matplotlib, and prettytable
import numpy as np
import matplotlib.pyplot as plt
from prettytable import PrettyTable
import csv

# --- Input Data ----------#
x = np.array([413,448,501,560,588,614,627,637], dtype=float)
y = np.array([0.243,0.262,0.296,0.329,0.348,0.357,0.370,0.374], dtype=float)
n = len(x)

# --- Data Table -----(Using PrettyTable)---#
table_data = PrettyTable(["i", "x", "y", "x²", "xy"])
for i in range(n):
    table_data.add_row([i+1, round(x[i], 3), round(y[i], 3), round(x[i]**2, 3), round(x[i]*y[i], 3)])
table_data.add_row(["Σ", round(np.sum(x), 3), round(np.sum(y), 3), round(np.sum(x**2), 3), round(np.sum(x*y), 3)])
table_data.title = "Input Data"
print(table_data, "\n")

# --- Least Squares Calculation ------#
Sx = np.sum(x)
Sy = np.sum(y)
Sxx = np.sum(x**2)
Sxy = np.sum(x*y)

delta = n*Sxx - Sx**2
a1 = (n*Sxy - Sx*Sy) / delta  # Slope
a0 = (Sxx*Sy - Sx*Sxy) / delta  # Intercept

# --- Error Analysis ---------#
y_fit = a0 + a1*x
residuals = y - y_fit
sigma_y = np.sqrt(np.sum(residuals**2) / (n-2))
sigma_a1 = sigma_y * np.sqrt(n / delta)
sigma_a0 = sigma_y * np.sqrt(Sxx / delta)

# --- Results Table ----------#
results = PrettyTable(["Parameter", "Value", "Uncertainty"])
results.title = "Fit Results & Statistical Errors"
results.add_row(["Slope (a₁)", f"{a1:.5f}", f"±{sigma_a1:.5f}"])
results.add_row(["Intercept (a₀)", f"{a0:.5f}", f"±{sigma_a0:.5f}"])
results.add_row(["σ_y (Std. Error)", f"{sigma_y:.5f}", ""])
results.add_row(["Δ (delta)", f"{delta:.5f}", ""])
print(results, "\n")

# --- Fitted Values Table ----------#
fit_table = PrettyTable(["x", "y (measured)", "y (fit)"])
fit_table.title = "Measured vs Fitted Values"
for xi, yi, yfi in zip(x, y, y_fit):
    fit_table.add_row([round(xi, 3), round(yi, 3), round(yfi, 3)])
print(fit_table, "\n")

# --- Save Input Data Table as CSV ---#
with open("InputData.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(table_data.field_names)
    for row in table_data._rows:
        writer.writerow(row)

# --- Save Results Table as CSV ---#
with open("FitResults.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(results.field_names)
    for row in results._rows:
        writer.writerow(row)

# --- Save Fitted Values Table as CSV ---#
with open("FittedValues.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(fit_table.field_names)
    for row in fit_table._rows:
        writer.writerow(row)

# --- Plotting ----#
plt.figure(figsize=(7,5))
plt.scatter(x, y, color='navy', label='Measured Data', s=40)
plt.plot(x, y_fit, color='crimson', linewidth=2,
         label=f'Least Squares Fit:\n$y = ({a1:.5f} \pm {sigma_a1:.5f})x + ({a0:.5f} \pm {sigma_a0:.5f})$')
plt.xlabel("Wavelength $\lambda $ (in nm)", fontsize=12)
plt.ylabel("$sin(\Theta)$", fontsize=12)
plt.title("$\lambda $ vs $sin(\Theta)$ Linear fit", fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# +-------------------------------------------+
# |                 Input Data                |
# +---+--------+-------+-----------+----------+
# | i |   x    |   y   |     x²    |    xy    |
# +---+--------+-------+-----------+----------+
# | 1 | 413.0  | 0.243 |  170569.0 | 100.359  |
# | 2 | 448.0  | 0.262 |  200704.0 | 117.376  |
# | 3 | 501.0  | 0.296 |  251001.0 | 148.296  |
# | 4 | 560.0  | 0.329 |  313600.0 |  184.24  |
# | 5 | 588.0  | 0.348 |  345744.0 | 204.624  |
# | 6 | 614.0  | 0.357 |  376996.0 | 219.198  |
# | 7 | 627.0  |  0.37 |  393129.0 |  231.99  |
# | 8 | 637.0  | 0.374 |  405769.0 | 238.238  |
# | Σ | 4388.0 | 2.579 | 2457512.0 | 1444.321 |
# +---+--------+-------+-----------+----------+
#
# +-----------------------------------------------+
# |        Fit Results & Statistical Errors       |
# +------------------+--------------+-------------+
# |    Parameter     |    Value     | Uncertainty |
# +------------------+--------------+-------------+
# |    Slope (a₁)    |   0.00059    |   ±0.00001  |
# |  Intercept (a₀)  |   0.00060    |   ±0.00525  |
# | σ_y (Std. Error) |   0.00213    |             |
# |    Δ (delta)     | 405552.00000 |             |
# +------------------+--------------+-------------+
#
# +--------------------------------+
# |   Measured vs Fitted Values    |
# +-------+--------------+---------+
# |   x   | y (measured) | y (fit) |
# +-------+--------------+---------+
# | 413.0 |    0.243     |  0.243  |
# | 448.0 |    0.262     |  0.263  |
# | 501.0 |    0.296     |  0.295  |
# | 560.0 |    0.329     |  0.329  |
# | 588.0 |    0.348     |  0.346  |
# | 614.0 |    0.357     |  0.361  |
# | 627.0 |     0.37     |  0.368  |
# | 637.0 |    0.374     |  0.374  |
# +-------+--------------+---------+

# %%
# Least Square Fitting with Error Analysis
# Using numpy, matplotlib, and prettytable
import numpy as np
import matplotlib.pyplot as plt
from prettytable import PrettyTable
import csv

# --- Input Data -------------#
x = np.array([0.1389,0.1875,0.21], dtype=float)
y = np.array([1.49,2.02,2.26], dtype=float)
n = len(x)

# --- Data Table ----------#
table_data = PrettyTable(["i", "x", "y", "x²", "xy"])
for i in range(n):
    table_data.add_row([i+1, round(x[i], 3), round(y[i], 3), round(x[i]**2, 3), round(x[i]*y[i], 4)])
table_data.add_row(["Σ", round(np.sum(x), 3), round(np.sum(y), 3), round(np.sum(x**2), 3), round(np.sum(x*y), 4)])
table_data.title = "Input Data"
print(table_data, "\n")

# --- Least Squares Calculation ---#
Sx = np.sum(x)
Sy = np.sum(y)
Sxx = np.sum(x**2)
Sxy = np.sum(x*y)

delta = n*Sxx - Sx**2
a1 = (n*Sxy - Sx*Sy) / delta  # Slope
a0 = (Sxx*Sy - Sx*Sxy) / delta  # Intercept

# --- Error Analysis -------#
y_fit = a0 + a1*x
residuals = y - y_fit
sigma_y = np.sqrt(np.sum(residuals**2) / (n-2))
sigma_a1 = sigma_y * np.sqrt(n / delta)
sigma_a0 = sigma_y * np.sqrt(Sxx / delta)

# --- Results Table --------#
results = PrettyTable(["Parameter", "Value", "Uncertainty"])
results.title = "Fit Results & Statistical Errors"
results.add_row(["Slope (a₁)", f"{a1:.5f}", f"±{sigma_a1:.5f}"])
results.add_row(["Intercept (a₀)", f"{a0:.5f}", f"±{sigma_a0:.5f}"])
results.add_row(["σ_y (Std. Error)", f"{sigma_y:.5f}", ""])
results.add_row(["Δ (delta)", f"{delta:.5f}", ""])
print(results, "\n")

# --- Fitted Values Table ---#
fit_table = PrettyTable(["x", "y (measured)", "y (fit)"])
fit_table.title = "Measured vs Fitted Values"
for xi, yi, yfi in zip(x, y, y_fit):
    fit_table.add_row([round(xi, 3), round(yi, 3), round(yfi, 3)])
print(fit_table, "\n")

# --- Save Input Data Table as CSV ---#
with open("InputData.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(table_data.field_names)
    for row in table_data._rows:
        writer.writerow(row)

# --- Save Results Table as CSV ---#
with open("FitResults.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(results.field_names)
    for row in results._rows:
        writer.writerow(row)

# --- Save Fitted Values Table as CSV ---#
with open("FittedValues.csv", "w", newline='') as f:
    writer = csv.writer(f)
    writer.writerow(fit_table.field_names)
    for row in fit_table._rows:
        writer.writerow(row)

# --- Plotting ---#
plt.figure(figsize=(7,5))
plt.scatter(x, y, color='navy', label='Measured Data', s=40)
plt.plot(x, y_fit, color='crimson', linewidth=2,
         label=f'Least Squares Fit:\n$y = ({a1:.5f} \pm {sigma_a1:.5f})x + ({a0:.5f} \pm {sigma_a0:.5f})$')
plt.ylabel("$1/\lambda$ (in $nm^{-1}$)", fontsize=12)
plt.xlabel("$(1/n^2 - 1/m^2)$", fontsize=12)
plt.title(" $1/\lambda$ vs $(1/n^2 - 1/m^2)$Linear Fit", fontsize=14)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# +-----------------------------------+
# |             Input Data            |
# +---+-------+------+-------+--------+
# | i |   x   |  y   |   x²  |   xy   |
# +---+-------+------+-------+--------+
# | 1 | 0.139 | 1.49 | 0.019 | 0.207  |
# | 2 | 0.188 | 2.02 | 0.035 | 0.3788 |
# | 3 |  0.21 | 2.26 | 0.044 | 0.4746 |
# | Σ | 0.536 | 5.77 | 0.099 | 1.0603 |
# +---+-------+------+-------+--------+
#
# +-------------------------------------------+
# |      Fit Results & Statistical Errors     |
# +------------------+----------+-------------+
# |    Parameter     |  Value   | Uncertainty |
# +------------------+----------+-------------+
# |    Slope (a₁)    | 10.84191 |   ±0.05705  |
# |  Intercept (a₀)  | -0.01520 |   ±0.01034  |
# | σ_y (Std. Error) | 0.00293  |             |
# |    Δ (delta)     | 0.00792  |             |
# +------------------+----------+-------------+
#
# +--------------------------------+
# |   Measured vs Fitted Values    |
# +-------+--------------+---------+
# |   x   | y (measured) | y (fit) |
# +-------+--------------+---------+
# | 0.139 |     1.49     |  1.491  |
# | 0.188 |     2.02     |  2.018  |
# |  0.21 |     2.26     |  2.262  |
# +-------+--------------+---------+
